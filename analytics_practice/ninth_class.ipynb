# %%
import pandas as pd
events = pd. read_csv("events1.csv")
events.head()
# Out:
#    user_id  ga_session_id country   device         type  item_id  \
# 0     2133          16909      US   mobile     purchase       94
# 1     2133          16909      US   mobile     purchase      425
# 2     5789          16908      SE  desktop     purchase        1
# 3     5789          16908      SE  desktop     purchase       62
# 4     5808           4267      US   mobile  add_to_cart      842
#
#                   date
# 0  2020-11-01 00:27:14
# 1  2020-11-01 00:27:14
# 2  2020-11-01 01:44:44
# 3  2020-11-01 01:44:44
# 4  2020-11-01 03:06:29

# %%
events.head(20)
# Out:
#     user_id  ga_session_id country   device         type  item_id  \
# 0      2133          16909      US   mobile     purchase       94
# 1      2133          16909      US   mobile     purchase      425
# 2      5789          16908      SE  desktop     purchase        1
# 3      5789          16908      SE  desktop     purchase       62
# 4      5808           4267      US   mobile  add_to_cart      842
# 5      5808           4267      US   mobile  add_to_cart      951
# 6      5808           4267      US   mobile  add_to_cart      950
# 7      5808           4267      US   mobile  add_to_cart     1068
# 8      5808           4267      US   mobile  add_to_cart      862
# 9      5808           4267      US   mobile  add_to_cart     1119
# 10     5808           4267      US   mobile  add_to_cart      252
# 11     5808           4267      US   mobile  add_to_cart     1085
# 12     5808           4267      US   mobile  add_to_cart     1074
# ...

# %%
events.describe()
# Out:
#              user_id  ga_session_id        item_id
# count  758884.000000  758884.000000  758884.000000
# mean    29541.809665    3632.325492     885.629356
# std     55129.337846    3952.875337     289.267126
# min         1.000000       0.000000       0.000000
# 25%      8401.000000     625.000000     913.000000
# 50%     17181.000000    2103.000000     972.000000
# 75%     25809.000000    5365.000000    1040.000000
# max    270145.000000   18033.000000    1380.000000

# %%
items = pd.read_csv("items.csv")

items.head(30)
# Out:
#     id                                    name   brand             variant  \
# 0    0            Google Land & Sea Cotton Cap  Google  Single Option Only
# 1    1                          Google KeepCup  Google  Single Option Only
# 2    2  Google Land & Sea Nalgene Water Bottle  Google  Single Option Only
# 3    3             Google Unisex Eco Tee Black  Google                  LG
# 4    4            Google Chicago Campus Bottle  Google  Single Option Only
# 5    5             Google SF Campus Zip Hoodie  Google                  LG
# 6    6        Google Chicago Campus Unisex Tee  Google                  MD
# 7    7             Google SF Campus Unisex Tee  Google                  SM
# 8    8                  Super G Unisex Joggers  Google                  LG
# 9    9              Mommy Works at Google Book  Google  Single Option Only
# 10  10              BLM Unisex Pullover Hoodie  Google                  MD
# ...

# %%
# How many unique items are in the data?
print(len(items ['name'].unique()))
items
# Out:
# 421
#         id                                    name   brand  \
# 0        0            Google Land & Sea Cotton Cap  Google
# 1        1                          Google KeepCup  Google
# 2        2  Google Land & Sea Nalgene Water Bottle  Google
# 3        3             Google Unisex Eco Tee Black  Google
# 4        4            Google Chicago Campus Bottle  Google
# ...    ...                                     ...     ...
# 1376  1376               Google Tritan Bottle Gray  Google
# 1377  1377              White Google Cloud Tumbler  Google
# 1378  1378               Google Separating Keyring  Google
# 1379  1379      Google Mountain View Campus Bottle  Google
# 1380  1380        Google Boulder Campus Ladies Tee  Google
#
#                  variant             category  price_in_usd
# 0     Single Option Only              Apparel            14
# 1     Single Option Only                  New            28
# 2     Single Option Only            Drinkware            20
# ...

# %%
# how many variants?
len(items['variant'].head())
# Out:
# 5

# %%
# What's the total cost of the items available for purchase?
#items. head (30)
print(f"${sum(items['price_in_usd']):,.2f}")
# Out:
# $36,352.00

# %%
#print(items.head())
events.head()
# Out:
#    user_id  ga_session_id country   device         type  item_id  \
# 0     2133          16909      US   mobile     purchase       94
# 1     2133          16909      US   mobile     purchase      425
# 2     5789          16908      SE  desktop     purchase        1
# 3     5789          16908      SE  desktop     purchase       62
# 4     5808           4267      US   mobile  add_to_cart      842
#
#                   date
# 0  2020-11-01 00:27:14
# 1  2020-11-01 00:27:14
# 2  2020-11-01 01:44:44
# 3  2020-11-01 01:44:44
# 4  2020-11-01 03:06:29

# %%
items['item_id'] = items['id']
items
# Out:
#         id                                    name   brand  \
# 0        0            Google Land & Sea Cotton Cap  Google
# 1        1                          Google KeepCup  Google
# 2        2  Google Land & Sea Nalgene Water Bottle  Google
# 3        3             Google Unisex Eco Tee Black  Google
# 4        4            Google Chicago Campus Bottle  Google
# ...    ...                                     ...     ...
# 1376  1376               Google Tritan Bottle Gray  Google
# 1377  1377              White Google Cloud Tumbler  Google
# 1378  1378               Google Separating Keyring  Google
# 1379  1379      Google Mountain View Campus Bottle  Google
# 1380  1380        Google Boulder Campus Ladies Tee  Google
#
#                  variant             category  price_in_usd  item_id
# 0     Single Option Only              Apparel            14        0
# 1     Single Option Only                  New            28        1
# ...

# %%
merged_df = pd.merge(events, items, on = "item_id")
merged_df
# Out:
#         user_id  ga_session_id country   device         type  item_id  \
# 0          2133          16909      US   mobile     purchase       94
# 1         10904          16401      TR  desktop     purchase       94
# 2         18869          15381      IN  desktop     purchase       94
# 3          7475          15302      TR   mobile     purchase       94
# 4         27000          17448      US   mobile     purchase       94
# ...         ...            ...     ...      ...          ...      ...
# 758879    11249           7300      IN   mobile     purchase      241
# 758880    14878           1683      US  desktop  add_to_cart     1379
# 758881     1012           1437      KR  desktop  add_to_cart     1379
# 758882    13090           1684      RU  desktop  add_to_cart     1379
# 758883    15448           2488      US  desktop  add_to_cart     1372
#
#                        date    id                                name   brand  \
# ...

# %%
merged_df[(merged_df['name'] == "Google Large Tote White")]
# Out:
#         user_id  ga_session_id country   device         type  item_id  \
# 0          2133          16909      US   mobile     purchase       94
# 1         10904          16401      TR  desktop     purchase       94
# 2         18869          15381      IN  desktop     purchase       94
# 3          7475          15302      TR   mobile     purchase       94
# 4         27000          17448      US   mobile     purchase       94
# ...         ...            ...     ...      ...          ...      ...
# 593016     4540           7994      IN   mobile  add_to_cart      967
# 593017     4540           7994      IN   mobile  add_to_cart      967
# 593018    14870           1166      US  desktop  add_to_cart      967
# 593019    14870           1166      US  desktop  add_to_cart      967
# 593020   251118          12452      US  desktop  add_to_cart      967
#
#                        date   id                     name   brand  \
# ...

# %%
# Total cost of items purchased

merged_df
# Out:
#         user_id  ga_session_id country   device         type  item_id  \
# 0          2133          16909      US   mobile     purchase       94
# 1         10904          16401      TR  desktop     purchase       94
# 2         18869          15381      IN  desktop     purchase       94
# 3          7475          15302      TR   mobile     purchase       94
# 4         27000          17448      US   mobile     purchase       94
# ...         ...            ...     ...      ...          ...      ...
# 758879    11249           7300      IN   mobile     purchase      241
# 758880    14878           1683      US  desktop  add_to_cart     1379
# 758881     1012           1437      KR  desktop  add_to_cart     1379
# 758882    13090           1684      RU  desktop  add_to_cart     1379
# 758883    15448           2488      US  desktop  add_to_cart     1372
#
#                        date    id                                name   brand  \
# ...

# %%
total_purchased = merged_df[(merged_df["type"] == "purchase" )]
total_purchased.head(40)
# Out:
#      user_id  ga_session_id country   device      type  item_id  \
# 0       2133          16909      US   mobile  purchase       94
# 1      10904          16401      TR  desktop  purchase       94
# 2      18869          15381      IN  desktop  purchase       94
# 3       7475          15302      TR   mobile  purchase       94
# 4      27000          17448      US   mobile  purchase       94
# 5      27001          16431      PT   mobile  purchase       94
# 6      16165          15834      US   mobile  purchase       94
# 7       8255          10575      US   mobile  purchase       94
# 8       8159          15166      US  desktop  purchase       94
# 9      12848          15836      RU  desktop  purchase       94
# 10     19481          10754      GB  desktop  purchase       94
# 11      2236          15515      MY  desktop  purchase       94
# 12      1056          10757      US   mobile  purchase       94
# 14      6635          16144      IL   mobile  purchase       94
# ...

# %%
print(f"${sum(total_purchased['price_in_usd']):,.2f}")
# Out:
# $307,114.00

# %%
total_purchased = merged_df[(merged_df["type"] != "purchase" )]
total_purchased.head(10)
# Out:
#     user_id  ga_session_id country   device            type  item_id  \
# 13    28230           3339      ZA   mobile     add_to_cart       94
# 15    24633           8976      US  desktop     add_to_cart       94
# 16    21001          11502      US  desktop     add_to_cart       94
# 17    22685           1129      US  desktop     add_to_cart       94
# 18    22685           1129      US  desktop     add_to_cart       94
# 20    11073           2167      US   mobile     add_to_cart       94
# 28     4605          15969      BG  desktop  begin_checkout       94
# 29     4605          15969      BG  desktop  begin_checkout       94
# 32    11478           5194      GB  desktop  begin_checkout       94
# 33    11478           5194      GB  desktop  begin_checkout       94
#
#                    date  id                     name   brand  \
# 13  2020-11-17 02:29:36  94  Google Large Tote White  Google
# 15  2020-11-17 06:57:19  94  Google Large Tote White  Google
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

plt.figure(figsize=(10, 6))
sns.histplot(merged_df['price_in_usd']) 
plt.title('Frequency vs Prices')
plt.xlabel('$USD')
plt.gca().xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f"${x:,.0f}"))
plt.ylabel('Frequency')
plt.show()

# %%
merged_df['date'] = pd.to_datetime(merged_df['date'])
merged_df
# Out:
#         user_id  ga_session_id country   device         type  item_id  \
# 0          2133          16909      US   mobile     purchase       94
# 1         10904          16401      TR  desktop     purchase       94
# 2         18869          15381      IN  desktop     purchase       94
# 3          7475          15302      TR   mobile     purchase       94
# 4         27000          17448      US   mobile     purchase       94
# ...         ...            ...     ...      ...          ...      ...
# 758879    11249           7300      IN   mobile     purchase      241
# 758880    14878           1683      US  desktop  add_to_cart     1379
# 758881     1012           1437      KR  desktop  add_to_cart     1379
# 758882    13090           1684      RU  desktop  add_to_cart     1379
# 758883    15448           2488      US  desktop  add_to_cart     1372
#
#                       date    id                                name   brand  \
# ...

# %%
df_daily = merged_df.resample('D', on="date").sum()
df_daily
# Out:
#               user_id  ga_session_id  \
# date
# 2020-11-01     714679         743344
# 2020-11-02    2695061        2214017
# 2020-11-03    2385599        2294513
# 2020-11-04    1922715        1821122
# 2020-11-05    1386529        1479344
# ...               ...            ...
# 2021-01-27  229005184       40807076
# 2021-01-28  225198652       31342165
# 2021-01-29  208260668       26322184
# 2021-01-30  163774654       17931337
# 2021-01-31  125364424       16785660
#
#                                                       country  \
# date
# 2020-11-01  USUSSESEUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# 2020-11-02  USUSUSUSCACACACACACACACACACAUSUSINUSUSUSUSUSUS...
# 2020-11-03  USUSUSUSUSUSECECECUSUSUSUSVNVNVNVNVNVNVNRUUSUS...
# 2020-11-04  CACACACACACACACACACASGSGSGSGSGSGCAATATATIEIEIE...
# 2020-11-05  USBRBRUSCACACACACACACACACACACACACACACACACACAUS...
# ...                                                       ...
# ...

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x=df_daily.index, y=count, data=df_daily)
plt.title('Purchases over Time')
plt.xlabel('Date')
plt.ylabel('Quantity')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 plt.figure(figsize=(10, 6))
# ----> 2 sns.lineplot(x=df_daily.index, y=count, data=df_daily)
#       3 plt.title('Purchases over Time')
#       4 plt.xlabel('Date')
#
# NameError: name 'count' is not defined

# %%
import pandas as pd
dataset = pd.read_csv("./Glassdoor_Salary_Cleaned_Version.csv")
dataset.describe() # best way to look at is by using describe
# Out:
#            Rating      Founded      hourly  employer_provided  min_salary  \
# count  742.000000   742.000000  742.000000         742.000000  742.000000
# mean     3.618868  1837.154987    0.032345           0.022911   74.068733
# std      0.801210   497.183763    0.177034           0.149721   31.869282
# min     -1.000000    -1.000000    0.000000           0.000000   10.000000
# 25%      3.300000  1939.000000    0.000000           0.000000   52.000000
# 50%      3.700000  1988.000000    0.000000           0.000000   69.500000
# 75%      4.000000  2007.000000    0.000000           0.000000   91.000000
# max      5.000000  2019.000000    1.000000           1.000000  202.000000
#
#        max_salary  avg_salary  same_state         age   python_yn        R_yn  \
# count  742.000000  742.000000  742.000000  742.000000  742.000000  742.000000
# mean   127.183288  100.626011    0.557951   46.591644    0.528302    0.002695
# ...

# %%
dataset.T # transposes the data or specifically returns a matrix that is obtained by interchanging the rows and columns
# Out:
#                                                                  0    \
# Job Title                                             Data Scientist
# Salary Estimate                           $53K-$91K (Glassdoor est.)
# Job Description    Data Scientist\nLocation: Albuquerque, NM\nEdu...
# Rating                                                           3.8
# Company Name                                  Tecolote Research\n3.8
# Location                                             Albuquerque, NM
# Headquarters                                              Goleta, CA
# Size                                           501 to 1000 employees
# Founded                                                         1973
# Type of ownership                                  Company - Private
# Industry                                         Aerospace & Defense
# Sector                                           Aerospace & Defense
# Revenue                                    $50 to $100 million (USD)
# ...

# %%
dataset.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %%
dataset.avg_salary
# Out:
# 0       72.0
# 1       87.5
# 2       85.0
# 3       76.5
# 4      114.5
#        ...
# 737     84.5
# 738    102.5
# 739     73.5
# 740    127.5
# 741     93.5
# Name: avg_salary, Length: 742, dtype: float64

# %%
dataset.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %%
sum(dataset.avg_salary)
# Out:
# 74664.5

# %%
len(dataset.avg_salary)
# Out:
# 742

# %%
sum(dataset.avg_salary)/len(dataset.avg_salary)
# Out:
# 100.62601078167116

# %%
dataset.avg_salary.mean()
# Out:
# 100.62601078167116

# %%
dataset.avg_salary.std()
# Out:
# 38.85594815651248

# %%
dataset['min_employees'] = dataset['Size'].str.split("to")
dataset['min_employees']
# Out:
# 0       [501 ,  1000 employees]
# 1            [10000+ employees]
# 2       [501 ,  1000 employees]
# 3      [1001 ,  5000 employees]
# 4         [51 ,  200 employees]
#                  ...
# 737          [10000+ employees]
# 738    [1001 ,  5000 employees]
# 739     [501 ,  1000 employees]
# 740         [1 ,  50 employees]
# 741     [501 ,  1000 employees]
# Name: min_employees, Length: 742, dtype: object

# %%
dataset[['min_employees', 'max_employees']] = dataset['Size'].str.split("to", expand=True)
dataset.T
# Out:
#                                                                  0    \
# Job Title                                             Data Scientist
# Salary Estimate                           $53K-$91K (Glassdoor est.)
# Job Description    Data Scientist\nLocation: Albuquerque, NM\nEdu...
# Rating                                                           3.8
# Company Name                                  Tecolote Research\n3.8
# Location                                             Albuquerque, NM
# Headquarters                                              Goleta, CA
# Size                                           501 to 1000 employees
# Founded                                                         1973
# Type of ownership                                  Company - Private
# Industry                                         Aerospace & Defense
# Sector                                           Aerospace & Defense
# Revenue                                    $50 to $100 million (USD)
# ...

# %%
dataset['max_employees'] = dataset['max_employees'].str.replace("employees","")

# %%
dataset['max_employees'].head(50)
# Out:
# 0       1000
# 1        None
# 2       1000
# 3       5000
# 4        200
# 5        500
# 6       1000
# 7        500
# 8        None
# 9        200
# 10      1000
# 11     10000
# 12       None
# 13       500
# 14       None
# 15      5000
# 16       200
# 17       500
# 18       200
# 19      1000
# 20       500
# 21       500
# 22      1000
# 23       200
# 24      1000
# 25       None
# 26      5000
# 27     10000
# 28       None
# 29      1000
# 30      5000
# 31      5000
# 32       None
# 33     10000
# 34       500
# 35       500
# 36      5000
# 37       500
# 38     10000
# 39       500
# 40       500
# 41        50
# 42       200
# 43     10000
# 44      5000
# 45       None
# 46       None
# 47     10000
# 48      1000
# 49       None
# Name: max_employees, dtype: object

# %%
print(dataset['max_employees'][49])
# Out:
# None

# %%
dataset['min_employees'].head(50)
# Out:
# 0                 501
# 1     10000+ employees
# 2                 501
# 3                1001
# 4                  51
# 5                 201
# 6                 501
# 7                 201
# 8     10000+ employees
# 9                  51
# 10                501
# 11               5001
# 12    10000+ employees
# 13                201
# 14    10000+ employees
# 15               1001
# 16                 51
# 17                201
# 18                 51
# 19                501
# 20                201
# 21                201
# 22                501
# 23                 51
# 24                501
# 25    10000+ employees
# 26               1001
# 27               5001
# 28    10000+ employees
# 29                501
# 30               1001
# 31               1001
# 32    10000+ employees
# 33               5001
# 34                201
# 35                201
# 36               1001
# 37                201
# 38               5001
# 39                201
# 40                201
# ...

# %%
print(dataset['max_employees'][40])
# Out:
#  500

# %%
dataset['max_employees'] = dataset['max_employees'].replace('None', 10000)

# %%
dataset['max_employees'].head(50)
# Out:
# 0       1000
# 1        None
# 2       1000
# 3       5000
# 4        200
# 5        500
# 6       1000
# 7        500
# 8        None
# 9        200
# 10      1000
# 11     10000
# 12       None
# 13       500
# 14       None
# 15      5000
# 16       200
# 17       500
# 18       200
# 19      1000
# 20       500
# 21       500
# 22      1000
# 23       200
# 24      1000
# 25       None
# 26      5000
# 27     10000
# 28       None
# 29      1000
# 30      5000
# 31      5000
# 32       None
# 33     10000
# 34       500
# 35       500
# 36      5000
# 37       500
# 38     10000
# 39       500
# 40       500
# 41        50
# 42       200
# 43     10000
# 44      5000
# 45       None
# 46       None
# 47     10000
# 48      1000
# 49       None
# Name: max_employees, dtype: object

# %%
dataset['max_employees'] = dataset['max_employees'].dropna()

# %%
dataset['max_employees'].head(50)
# Out:
# 0       1000
# 1         NaN
# 2       1000
# 3       5000
# 4        200
# 5        500
# 6       1000
# 7        500
# 8         NaN
# 9        200
# 10      1000
# 11     10000
# 12        NaN
# 13       500
# 14        NaN
# 15      5000
# 16       200
# 17       500
# 18       200
# 19      1000
# 20       500
# 21       500
# 22      1000
# 23       200
# 24      1000
# 25        NaN
# 26      5000
# 27     10000
# 28        NaN
# 29      1000
# 30      5000
# 31      5000
# 32        NaN
# 33     10000
# 34       500
# 35       500
# 36      5000
# 37       500
# 38     10000
# 39       500
# 40       500
# 41        50
# 42       200
# 43     10000
# 44      5000
# 45        NaN
# 46        NaN
# 47     10000
# 48      1000
# 49        NaN
# Name: max_employees, dtype: object
